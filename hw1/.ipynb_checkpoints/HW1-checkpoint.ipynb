# %%
import numpy as np
import os

# %%
TOP_N_WORDS = 1500
VOCAB_PATH = "/home/lenny/Documents/PROGRAMMING/CSCI4967/hw1/aclImdb/imdb.vocab"
TRAIN_PATH = "/home/lenny/Documents/PROGRAMMING/CSCI4967/hw1/aclImdb/train"

# %%
##Construct a vocabulary using the top N words
f = open(VOCAB_PATH, 'r')
vocab = f.readlines()[:TOP_N_WORDS]
vocab_list = [word.strip() for word in vocab]
word_index = { vocab_list[i] : i for i in range(len(vocab_list)) }
#print(word_index)
#print(vocab)
# Out:
# {'the': 0, 'and': 1, 'a': 2, 'of': 3, 'to': 4, 'is': 5, 'it': 6, 'in': 7, 'i': 8, 'this': 9, 'that': 10, 'was': 11, 'as': 12, 'for': 13, 'with': 14, 'movie': 15, 'but': 16, 'film': 17, 'on': 18, 'not': 19, 'you': 20, 'he': 21, 'are': 22, 'his': 23, 'have': 24, 'be': 25, 'one': 26, '!': 27, 'all': 28, 'at': 29, 'by': 30, 'an': 31, 'who': 32, 'they': 33, 'from': 34, 'so': 35, 'like': 36, 'there': 37, 'her': 38, 'or': 39, 'just': 40, 'about': 41, 'if': 42, 'has': 43, 'out': 44, 'what': 45, '?': 46, 'some': 47, 'good': 48, 'more': 49, 'when': 50, 'she': 51, 'very': 52, 'even': 53, 'my': 54, 'no': 55, 'up': 56, 'time': 57, 'would': 58, 'which': 59, 'only': 60, 'story': 61, 'really': 62, 'their': 63, 'see': 64, 'had': 65, 'can': 66, 'were': 67, 'me': 68, 'we': 69, 'than': 70, 'well': 71, 'much': 72, 'been': 73, 'get': 74, 'people': 75, 'will': 76, 'bad': 77, 'other': 78, 'also': 79, 'into': 80, 'do': 81, 'because': 82, 'great': 83, 'first': 84, 'how': 85, 'him': 86, 'most': 87, "don't": 88, 'its': 89, 'made': 90, 'then': 91, 'them': 92, 'way': 93, 'make': 94, 'could': 95, 'too': 96, 'any': 97, 'after': 98, 'movies': 99, 'think': 100, 'characters': 101, 'character': 102, 'watch': 103, 'films': 104, 'two': 105, 'many': 106, 'seen': 107, 'being': 108, 'acting': 109, 'never': 110, 'plot': 111, 'little': 112, 'where': 113, 'love': 114, 'best': 115, 'life': 116, 'did': 117, 'show': 118, 'know': 119, 'does ever': 120, 'here': 121, 'better': 122, 'man': 123, 'your': 124, 'still': 125, 'end': 126, 'over': 127, 'off': 128, 'these': 129, 'say': 130, 'scene': 131, 'why': 132, 'while': 133, 'scenes': 134, 'such': 135, 'go': 136, 'something': 137, 'should': 138, 'through': 139, 'back': 140, "i'm": 141, 'those': 142, 'watching': 143, 'real': 144, 'though': 145, 'now': 146, "doesn't": 147, 'thing': 148, 'years': 149, 'actors': 150, 'director': 151, 'another': 152, "didn't": 153, 'before': 154, 'nothing': 155, 'new': 156, 'funny': 157, 'actually': 158, 'work': 159, 'makes': 160, 'find': 161, 'look': 162, 'old': 163, 'few': 164, 'going': 165, 'same': 166, 'again': 167, 'lot': 168, 'part': 169, 'every': 170, 'cast': 171, 'us': 172, 'world': 173, 'quite': 174, 'want': 175, 'things': 176, 'pretty': 177, 'young': 178, 'seems': 179, 'around': 180, 'got': 181, 'down': 182, 'however': 183, "can't": 184, 'fact': 185, 'horror': 186, 'take': 187, 'enough': 188, 'both': 189, 'may': 190, 'give': 191, 'original': 192, 'between': 193, 'big': 194, 'own': 195, "i've": 196, 'thought': 197, 'series': 198, 'without': 199, 'right': 200, 'times': 201, 'long': 202, 'always': 203, 'gets': 204, 'action': 205, 'comedy': 206, "isn't": 207, 'family': 208, 'come': 209, 'point': 210, 'role': 211, 'saw': 212, 'interesting': 213, 'almost': 214, 'least': 215, 'whole': 216, 'must': 217, 'bit': 218, 'music': 219, 'script': 220, 'done': 221, 'guy': 222, 'anything': 223, 'minutes': 224, 'last': 225, 'since': 226, 'might': 227, 'performance': 228, 'far': 229, 'feel': 230, 'probably': 231, 'am': 232, 'woman': 233, 'kind': 234, 'girl': 235, 'away': 236, 'yet': 237, 'rather': 238, 'worst': 239, 'sure': 240, 'fun': 241, 'anyone': 242, 'making': 243, 'each': 244, 'played': 245, 'tv': 246, 'found': 247, 'having': 248, 'day': 249, 'although': 250, 'especially': 251, 'our': 252, 'course': 253, 'believe': 254, 'comes': 255, 'trying': 256, 'goes': 257, 'hard': 258, 'looks': 259, 'different': 260, 'place': 261, 'book': 262, 'actor': 263, 'put': 264, 'maybe': 265, 'money': 266, 'someone': 267, 'ending': 268, 'reason': 269, 'let': 270, 'everything': 271, "wasn't": 272, 'sense': 273, 'once': 274, 'shows': 275, 'screen': 276, 'dvd': 277, 'true': 278, 'set': 279, 'worth': 280, 'job': 281, 'main': 282, 'looking': 283, 'watched': 284, 'everyone': 285, 'together': 286, 'three': 287, 'plays': 288, 'john': 289, 'later': 290, 'said': 291, 'play': 292, 'instead': 293, 'audience': 294, 'seem': 295, 'beautiful': 296, 'takes': 297, 'effects': 298, 'himself': 299, 'version': 300, 'during': 301, 'left': 302, 'nigh ...

# %%
#Collect the total amount of % of times each word was seen in a postive/negative review
#score = total_pos_appearences/ total_apperances
